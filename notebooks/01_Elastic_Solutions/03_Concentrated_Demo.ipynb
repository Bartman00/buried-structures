# %% [markdown]
# ## Concentrated Demonstration
#
# by: Brett Mattas
# <br>date: 6/19/2016
#
# ### Description
#
# Demonstration of concentrated load object.
#
# ### Included:
#
# 1. Stress in X, Y, and Z directions
# 2. Exploration near the singularity right under the load

# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import numpy as np
from math import pi
from buried_structures import Point_3d, Origin
import xarray as xr
from ipywidgets import Output
import plotly.io as pio
from IPython.display import display, HTML
from buried_structures import point, point_load
print("Finished Imports")
# Out:
# Import tests finished
# Finished Imports

# %%
# X, Y, Z Points over a typical range

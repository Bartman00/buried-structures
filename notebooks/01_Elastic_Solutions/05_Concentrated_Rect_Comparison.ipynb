# %% [markdown]
# ## Concentrated to Rectangular Comparison
#
# by: Brett Mattas
# <br>date: 6/27/2016
#
# ### Purpose
#
# The purpose of this notebook is to compare the difference between rectangular and concentrated loads.
#
# ### Included:
#
# 1. Item
# 2. Item
# 3. Item

# %%
import plotly.graph_objects as go
import numpy as np
from math import pi
import plotly.io as pio
pio.renderers.default = "notebook"
import sys
import pathlib

# Plotting helpers
target = pathlib.Path.cwd().parent / "notebook_helpers"
print(f"{target=}")
print(f"Found notebook_helpers:   {target.exists()}")
sys.path.append(str(target))
from plotting import volume_plot

# Buried structures
from buried_structures import Point_3d, Origin
from buried_structures import Rectangular_Load

print("Finished Imports")
